# %%
import os

# %%
os.listdir()
# Out:
# ['.emacs-19.el',
#  'miniconda.sh',
#  'miniconda3',
#  '.ipynb_checkpoints',
#  '.windows',
#  '.bash_history',
#  '.config',
#  'Miniconda3-latest-Linux-x86_64.sh',
#  '.emacs-22.el',
#  '.nv',
#  '=2.31.0',
#  '.emacs-21.el',
#  '.emacs',
#  '.ipython',
#  '.ssh',
#  '.bashrc',
#  'Miniconda3-latest-Linux-x86_64.sh.1',
#  'Untitled.ipynb',
#  '.cache',
#  '.local',
#  '.jupyter',
#  '.conda',
#  '.emacs-23.el',
#  '.emacs-20.el']
